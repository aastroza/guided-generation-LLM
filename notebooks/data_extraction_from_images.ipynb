# %% [markdown]
# # Chart to Table
#
# Code from here: https://github.com/jxnl/instructor/blob/main/examples/vision/run_table.py

# %%
import sys
sys.path.append('..')
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from io import StringIO
from typing import Annotated, Any, Iterable
from openai import OpenAI
from pydantic import (
    BaseModel,
    BeforeValidator,
    PlainSerializer,
    InstanceOf,
    WithJsonSchema,
)
import pandas as pd
import instructor


client = instructor.patch(OpenAI(), mode=instructor.function_calls.Mode.MD_JSON)


def to_markdown(df: pd.DataFrame) -> str:
    return df.to_markdown()


def md_to_df(data: Any) -> Any:
    if isinstance(data, str):
        return (
            pd.read_csv(
                StringIO(data),  # Get rid of whitespaces
                sep="|",
                index_col=1,
            )
            .dropna(axis=1, how="all")
            .iloc[1:]
            .map(lambda x: x.strip())
        )
    return data


MarkdownDataFrame = Annotated[
    InstanceOf[pd.DataFrame],
    BeforeValidator(md_to_df),
    PlainSerializer(to_markdown),
    WithJsonSchema(
        {
            "type": "string",
            "description": """
                The markdown representation of the table, 
                each one should be tidy, do not try to join tables
                that should be seperate""",
        }
    ),
]


class Table(BaseModel):
    caption: str
    dataframe: MarkdownDataFrame

TEXT_PROMPT = """
Extract the data from the image, and describe it as a table. 
Each row is shown with a center point, which value you want to estimate from the position in the graph. 
For example is a value is almost 0.2, so 0.196 would be a good estimate.
The order of the values is the most important aspect to get right. 
Also provide the upper and lower bounds for each bar.
"""

def extract_table(url: str) -> Iterable[Table]:
    return client.chat.completions.create(
        model="gpt-4-vision-preview",
        response_model=Iterable[Table],
        max_tokens=1800,
        temperature=0.0,
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": TEXT_PROMPT,
                    },
                    {
                        "type": "image_url",
                        "image_url": {"url": url},
                    },
                ],
            }
        ],
    )

# %% [markdown]
# <img src="https://files.gitbook.com/v0/b/gitbook-x-prod.appspot.com/o/spaces%2FRPAuLvXI0lCcTz39j3BR%2Fuploads%2FXWcseqee9uSvfbwjlD9O%2F0.png?alt=media" alt="sarcasm" width="800"/>

# %%
url = "https://files.gitbook.com/v0/b/gitbook-x-prod.appspot.com/o/spaces%2FRPAuLvXI0lCcTz39j3BR%2Fuploads%2FXWcseqee9uSvfbwjlD9O%2F0.png?alt=media"
tables = extract_table(url)

# %%
len(tables)
# Out:
# 1

# %%
tables[0].dataframe
# Out:
#                                                 Category   Estimate   \
#  Attribute
#  Gender                                            female       0.02
#  Gender                                              male       0.00
#  Education                                      no formal      -0.18
#  Education                                      4th grade      -0.14
#  Education                                      8th grade      -0.10
#  Education                                    high school      -0.06
#  Education                               two-year college      -0.02
#  Education                                 college degree       0.02
#  Education                                graduate degree       0.08
#  Language                                  fluent English       0.07
#  Language                                  broken English      -0.01
#  Language              tried English but used interpreter      -0.11
#  Origin                                           Germany       0.04
#  Origin                                            France       0.06
#  Origin                                            Mexico      -0.10
#  Origin                                       Philippines      -0.02
#  Origin                                            Poland      -0.04
#  Origin                                             India       0.00
#  Origin                                             China       0.02
#  Origin                                             Sudan      -0.14
#  Origin                                           Somalia      -0.16
#  Origin                                              Iraq      -0.18
#  Profession                                       janitor      -0.16
#  Profession                                        waiter      -0.14
#  Profession                                      gardener      -0.12
#  Profession                             financial analyst       0.10
#  Profession                           construction worker      -0.18
#  Profession                                       teacher       0.06
#  Profession                           computer programmer       0.14
#  Profession                                         nurse       0.12
#  Profession                            research scientist       0.18
#  Profession                                        doctor       0.20
#  Job experience                                      none      -0.12
#  Job experience                                 1-2 years      -0.08
#  Job experience                                 3-5 years      -0.04
#  Job experience                                  5+ years       0.00
#  Job plans                         contract with employer       0.14
#  Job plans                       interviews with employer       0.10
#  Job plans                             will look for work      -0.02
#  Job plans                      no plans to look for work      -0.18
#  Application reason                   reunite with family       0.00
#  Application reason                       seek better job       0.02
#  Application reason                    escape persecution      -0.02
#  Prior trips to U.S.                                never      -0.02
#  Prior trips to U.S.                      once as tourist       0.02
#  Prior trips to U.S.                many times as tourist       0.06
#  Prior trips to U.S.               six months with family       0.04
#  Prior trips to U.S.               once w/o authorization      -0.10
#
#                        Lower Bound   Upper Bound
#  Attribute
#  Gender                       -0.02          0.06
#  Gender                       -0.04          0.04
#  Education                    -0.22         -0.14
#  Education                    -0.18         -0.10
#  Education                    -0.14         -0.06
#  Education                    -0.10         -0.02
#  Education                    -0.06          0.02
#  Education                    -0.02          0.06
#  Education                     0.04          0.12
#  Language                      0.03          0.11
#  Language                     -0.05          0.03
#  Language                     -0.15         -0.07
#  Origin                        0.00          0.08
#  Origin                        0.02          0.10
#  Origin                       -0.14         -0.06
#  Origin                       -0.06          0.02
#  Origin                       -0.08          0.00
#  Origin                       -0.04          0.04
#  Origin                       -0.02          0.06
#  Origin                       -0.18         -0.10
#  Origin                       -0.20         -0.12
#  Origin                       -0.22         -0.14
#  Profession                   -0.20         -0.12
#  Profession                   -0.18         -0.10
#  Profession                   -0.16         -0.08
#  Profession                    0.06          0.14
#  Profession                   -0.22         -0.14
#  Profession                    0.02          0.10
#  Profession                    0.10          0.18
#  Profession                    0.08          0.16
#  Profession                    0.14          0.22
#  Profession                    0.16          0.24
#  Job experience               -0.16         -0.08
#  Job experience               -0.12         -0.04
#  Job experience               -0.08          0.00
#  Job experience               -0.04          0.04
#  Job plans                     0.10          0.18
#  Job plans                     0.06          0.14
#  Job plans                    -0.06          0.02
#  Job plans                    -0.22         -0.14
#  Application reason           -0.04          0.04
#  Application reason           -0.02          0.06
#  Application reason           -0.06          0.02
#  Prior trips to U.S.          -0.06          0.02
#  Prior trips to U.S.          -0.02          0.06
#  Prior trips to U.S.           0.02          0.10
#  Prior trips to U.S.           0.00          0.08
#  Prior trips to U.S.          -0.14         -0.06

# %% [markdown]
# <img src="https://thomasleeper.com/cregg/reference/amce-1.png" alt="sarcasm" width="800"/>

# %%
url = "https://thomasleeper.com/cregg/reference/amce-1.png"
tables = extract_table(url)

# %%
len(tables)
# Out:
# 1

# %%
tables[0].dataframe
# Out:
#                            Estimated AMCE   Lower Bound   Upper Bound
#  Feature
#  Male (Gender)                         0.2           0.1           0.3
#  Female (Gender)                      -0.2          -0.3          -0.1
#  Graduate Degree                       3.6           3.3           3.9
#  College Degree                        2.8           2.5           3.1
#  Two-Year College                      2.0           1.7           2.3
#  High School                           1.2           0.9           1.5
#  8th Grade                             0.4           0.1           0.7
#  4th Grade                            -0.4          -0.7          -0.1
#  No Formal                            -1.2          -1.5          -0.9
#  Used Interpreter                     -3.2          -3.5          -2.9
#  Tried English but Unable             -2.4          -2.7          -2.1
#  Broken English                       -1.6          -1.9          -1.3
#  Fluent English                       -0.8          -1.1          -0.5
